# %%
# Daten laden
df = pd.read_csv("daten.csv")

# 1. Welche Spalten gibt es wirklich exakt in dieser Datei?
print(df.columns)

# 2. Wie sehen die ersten 5 Zeilen aus?
display(df.head())

# 3. Welche Datentypen haben die Spalten (Text, Zahl, Datum)?
print(df.info())
