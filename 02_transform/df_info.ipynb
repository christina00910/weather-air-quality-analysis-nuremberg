# %%
import pandas as pd

# %%
df=pd.read_csv("Schadstoff_Wetter.csv")
#df.head(20)
df.describe()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 394488 entries, 0 to 394487
# Data columns (total 30 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   station                               394488 non-null  int64
#  1   datum                                 394488 non-null  str
#  2   stunde                                394488 non-null  int64
#  3   datumstunde                           394488 non-null  int64
#  4   qualitaetsniveau_temperatur           394463 non-null  float64
#  5   temperatur                            394449 non-null  float64
#  6   luftfeuchtigkeit                      394376 non-null  float64
#  7   qualitaetsniveau_windgeschwindigkeit  394235 non-null  float64
#  8   windgeschwindigkeit                   394165 non-null  float64
#  9   windrichtung                          394209 non-null  float64
# ...
