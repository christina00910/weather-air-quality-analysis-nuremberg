# %% [markdown]
# # 📓 Modul 3: Finales Training & App-Export
# **Ziel dieses Notebooks:** Wir haben unser "Gewinner-Modell" in Notebook 2 gefunden. Nun trainieren wir dieses Modell ein allerletztes Mal auf den *gesamten* verfügbaren Daten, damit es für das Streamlit-Dashboard so schlau wie möglich ist. Danach packen wir es in eine Datei.
#
# ## 📋 To-Do / Berechnungen:
# - [ ] **Daten-Import:** Einlesen der `train_ready_data.csv`.
# - [ ] **Finales Full-Fit:**
#     - Das ausgewählte Modell (z.B. Random Forest mit den besten Hyperparametern aus Notebook 2) auf **100% der Daten** (1980-2024) trainieren. Es gibt hier keinen Test-Split mehr!
# - [ ] **Modell serialisieren (Export):**
#     - Das fertige Modell mit `joblib` (oder `pickle`) als `final_model.pkl` speichern.
#     - Eigentlich werde die meisten Ergebnisse sowieso als json gespeichert und sind eicht zu integrieren
# - [ ] **Dummy-Test für die Streamlit-App:**
#     - Das Modell aus der `.pkl`-Datei neu laden.
#     - Eine kurze Funktion schreiben, die einen (fiktiven) Eingabe-Array simuliert, den das Dashboard später liefert (z.B. `Input = [25.5, 3.2, 7, 14]` für Temp, Wind, Monat, Stunde).
#     - Überprüfen, ob die `model.predict(Input)` Funktion einen sinnvollen Schadstoffwert ausspuckt.
